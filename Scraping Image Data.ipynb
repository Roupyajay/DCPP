# %% [markdown]
# # Fetching Image Data

# %%
#importing libraries
import requests
import io
import PIL
from PIL import Image
from io import BytesIO
import numpy as np
import urllib
from urllib.request import urlopen,Request

#Fetching Image
response=requests.get('https://img.etimg.com/photo/msid-90518715,quality-100/image-6.jpg')
image_bytes=io.BytesIO(response.content)

img1=PIL.Image.open(image_bytes)
imgarray=np.array(img1)
img_grey = img1.convert('L')
img = img_grey.save('savedimage.jpg')
img_grey
# Out:
# <PIL.Image.Image image mode=L size=721x343 at 0x2C2028186A0>
